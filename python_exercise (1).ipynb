# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

# --- Global Data for the Exercise (Simulated Data) ---
# We'll imagine this is sensor data from various devices.
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}

# --- Task 1: Python Fundamentals, Lists, Tuples, Sets, Dictionaries, Indexing & Slicing ---
print("\n--- Task 1: Data Generation and Basic Structures ---")

# 1.1 Generate a list of 100 simulated sensor readings.
#    Each reading should be a tuple: (timestamp_str, device_id, device_type, location, value).
#    - timestamp_str: Format as 'YYYY-MM-DD HH:MM:SS'
#    - device_id: A unique ID for each reading (e.g., 'DEV001', 'DEV002', etc., up to 100 unique IDs).
#    - device_type: Randomly chosen from DEVICE_TYPES.
#    - location: Randomly chosen from LOCATIONS.
#    - value: Random float within READING_RANGES for its device_type (round to 2 decimal places).
# Store these in a list called 'raw_sensor_data'.

# Your code for Task 1.1 here:
raw_sensor_data = []

start_time = datetime.datetime.now()

for i in range(1, 101):
    timestamp = (start_time + datetime.timedelta(seconds=i)).strftime("%Y-%m-%d %H:%M:%S")

    device_id = f"DEV{i:03d}"

    device_type = random.choice(DEVICE_TYPES)

    location = random.choice(LOCATIONS)

    min_val, max_val = READING_RANGES[device_type]

    value = round(random.uniform(min_val, max_val), 2)

    reading = (
        timestamp,
        device_id,
        device_type,
        location,
        value
    )

    raw_sensor_data.append(reading)

for reading in raw_sensor_data[:100]:
    print(reading)




# 1.2 From 'raw_sensor_data', create a list named 'temperature_readings' containing only the readings
#     where 'device_type' is 'Temperature_Sensor'.
#     Each item in 'temperature_readings' should be a dictionary with keys:
#     'timestamp', 'device_id', 'location', 'temperature_celsius'.

# Your code for Task 1.2 here:
temperature_readings = []

for reading in raw_sensor_data:

    timestamp = reading[0]
    device_id = reading[1]
    device_type = reading[2]
    location = reading[3]
    value = reading[4]

    if device_type == "Temperature_Sensor":

        temp = {
            "timestamp": timestamp,
            "device_id": device_id,
            "location": location,
            "temperature_celsius": value
        }

        temperature_readings.append(temp)

print(temperature_readings)



# 1.3 Create a set named 'unique_locations' containing all unique locations from 'raw_sensor_data'.

# Your code for Task 1.3 here:
unique_locations = set()
for reading in raw_sensor_data:
    unique_locations.add(reading[3])
print(unique_locations)


# 1.4 Create a dictionary named 'device_stats' where keys are 'device_type' and values are
#     a tuple: (min_value, max_value) observed for that device type across all readings.
#     Initialize with sensible large/small values.

# Your code for Task 1.4 here:
device_stats = {}
for device in DEVICE_TYPES:
    device_stats[device] = (float("inf"), float("-inf"))
for reading in raw_sensor_data:
    device_type = reading[2]
    value = reading[4]
    minimum, maximum = device_stats[device_type]
    if value < minimum:
        minimum = value
    if value > maximum:
        maximum = value
    device_stats[device_type] = (minimum,maximum)
print(device_stats)


# 1.5: Advanced Indexing and Slicing (Lists and Strings)
print("\n--- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---")

# Let's use 'raw_sensor_data' and create a sample string for these tasks.
sample_string = "PythonProgrammingIsFun"

# 1.5.1 List Slicing: Extract elements from the 10th to the 20th (inclusive) from 'raw_sensor_data'.
#       Store the result in 'sliced_readings_1'.
#       Then, extract every 5th reading from 'raw_sensor_data' starting from the beginning.
#       Store the result in 'sliced_readings_2'.

# Your code for Task 1.5.1 here:

sliced_readings_1 = raw_sensor_data[9:20]
sliced_readings_2 = raw_sensor_data[::5]
print(sliced_readings_1)
print(sliced_readings_2)

# 1.5.2 String Slicing: Extract the substring "Programming" from 'sample_string'.
#       Store the result in 'substring_1'.
#       Then, extract the substring "nohtyP" (the reverse of "Python") from 'sample_string' using slicing.
#       Store the result in 'substring_2'.

# Your code for Task 1.5.2 here:

sample_string = "PythonProgrammingIsFun"
sub_string_1 = sample_string[6:17]
sub_string_2 = sample_string[5::-1]
print(sub_string_1)
print(sub_string_2)

# 1.5.3 Mixed Slicing: Access the 'device_type' of the 5th reading in 'raw_sensor_data' using indexing.
#       Store it in 'fifth_reading_device_type'.
#       Then, from 'fifth_reading_device_type', extract the last 6 characters (e.g., 'Sensor' from 'Temperature_Sensor').
#       Store it in 'device_type_suffix'.

# Your code for Task 1.5.3 here:

fifth_reading_device_type = raw_sensor_data[4][2]
device_type_suffix = fifth_reading_device_type[-6::]
print(fifth_reading_device_type)
print(device_type_suffix)

# --- Task 2: Writing and Using Functions in Python ---
print("\n--- Task 2: Function Definitions and Usage ---")

# 2.1 Write a function `get_readings_by_location(readings_list, target_location)`
#     that takes the 'raw_sensor_data' list and a 'target_location' string.
#     It should return a list of all readings (as tuples) for that specific location.

# Your code for Task 2.1 here:

def get_readings_by_location(readings_list, target_location):
    location_readings = []
    for reading in readings_list:
        if reading[3] == target_location:
            location_readings.append(reading)
    return location_readings

# 2.2 Write a function `calculate_average_temperature(temp_data_list)`
#     that takes the 'temperature_readings' list (list of dictionaries).
#     It should calculate and return the average temperature. Return 0.0 if the list is empty.

# Your code for Task 2.2 here:

def calculate_average_temperature(temp_data_list):
    if len(temp_data_list) == 0:
        return 0.0
    total = 0
    for reading in temp_data_list:
        average = total / len(temp_data_list)
    return average

# 2.3 Write a function `generate_report_line(reading_dict)`
#     that takes a single temperature reading dictionary.
#     It should return a formatted string like:
#     "[{timestamp}] Device {device_id} at {location}: {temperature_celsius}°C"

# Your code for Task 2.3 here:

def generate_report_line(reading_dict):
    report = (f"[{reading_dict['timestamp']}]"
    f"Device {reading_dict['device_id']}"
    f"at {reading_dict['location']}: "
    f"{reading_dict['temperature_celsius']}C"
    )
    return report

# --- Task 3: Working with Core Python Libraries (os, datetime, random) ---
print("\n--- Task 3: Core Library Usage ---")

# 3.1 Use the `os` module to create a new directory named 'sensor_reports'
#     in the current working directory, if it doesn't already exist.

# Your code for Task 3.1 here:
reports_dir = 'sensor_reports'
if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"\nDirectory '{reports_dir}' created.")
else:
    print(f"\nDirectory '{reports_dir}' already exists.")


# 3.2 Calculate the duration between the first and last timestamp in 'raw_sensor_data'.
#     Convert string timestamps to datetime objects first.
#     Print the duration in days, hours, and minutes.

# Your code for Task 3.2 here:
if len(raw_sensor_data) > 1:
    first_timestamp_str = raw_sensor_data[0][0]
    last_timestamp_str = raw_sensor_data[-1][0]

    # Convert string to datetime object
    # The format string must exactly match the timestamp string
    date_format = '%Y-%m-%d %H:%M:%S'
    first_dt = datetime.datetime.strptime(first_timestamp_str, date_format)
    last_dt = datetime.datetime.strptime(last_timestamp_str, date_format)

    duration = last_dt - first_dt

    days = duration.days
    seconds = duration.total_seconds()
    hours = int(seconds // 3600) % 24 # Calculate remaining hours after full days
    minutes = int((seconds % 3600) // 60) # Calculate remaining minutes after full hours

    print(f"\nDuration of data collection: {days} days, {hours} hours, {minutes} minutes.")
else:
    print("\nNot enough data to calculate duration.")


# 3.3 Generate a list of 5 random integer values between 100 and 200 (inclusive)
#     using the `random` module. Store it in 'random_values'.

# Your code for Task 3.3 here:

random_values = []
for i in range(5):
    number = random.randint(100, 200)
    random_values.append(number)
print(random_values)

# --- Task 4: File Handling in Python ---
print("\n--- Task 4: File I/O ---")

# 4.1 Write all 'temperature_readings' to a file named 'sensor_reports/temperature_report.txt'.
#     Each line in the file should be generated using the `generate_report_line` function.

# Your code for Task 4.1 here:
report_filename = os.path.join(reports_dir, 'temperature_report.txt')
try:
    with open(report_filename, 'w') as f:
        for reading_dict in temperature_readings:
            line = generate_report_line(reading_dict)
            f.write(line + '\n')
    print(f"\nTemperature report written to '{report_filename}'.")
except IOError as e:
    print(f"\nError writing file '{report_filename}': {e}")


# 4.2 Read the content of 'sensor_reports/temperature_report.txt' back into a list of strings
#     named 'read_report_lines'. Print the first 3 lines.

# Your code for Task 4.2 here:

read_report_lines = []
try:
    with open(report_filename, "r") as file:
        read_report_lines = file.readlines()
    print("First 3 lines of the report: ")
    for line in read_report_lines[:3]:
        print(line.strip())
except IOError as e:
    print("Error reading file:", e)
print("\n--- Exercise Complete! ---")
print("Great job completing the intermediate Python exercise.")
print("Review your code and outputs to ensure correctness and understanding of all concepts.")
print("Consider adding more complex scenarios or user inputs for further practice.")
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# --- Task 1: Data Generation and Basic Structures ---
# ('2026-07-21 14:29:05', 'DEV001', 'Humidity_Sensor', 'OfficeA', 41.66)
# ('2026-07-21 14:29:06', 'DEV002', 'Pressure_Sensor', 'OfficeA', 1006.88)
# ('2026-07-21 14:29:07', 'DEV003', 'Temperature_Sensor', 'OfficeB', 21.8)
# ('2026-07-21 14:29:08', 'DEV004', 'Pressure_Sensor', 'Lab2', 987.25)
# ('2026-07-21 14:29:09', 'DEV005', 'Light_Sensor', 'Lab1', 940.06)
# ('2026-07-21 14:29:10', 'DEV006', 'Pressure_Sensor', 'OfficeB', 1020.41)
# ('2026-07-21 14:29:11', 'DEV007', 'Light_Sensor', 'Lab1', 880.45)
# ('2026-07-21 14:29:12', 'DEV008', 'Temperature_Sensor', 'Lab1', 28.96)
# ('2026-07-21 14:29:13', 'DEV009', 'Humidity_Sensor', 'Lab1', 49.61)
# ('2026-07-21 14:29:14', 'DEV010', 'Pressure_Sensor', 'OfficeA', 1001.42)
# ('2026-07-21 14:29:15', 'DEV011', 'Pressure_Sensor', 'OfficeB', 985.68)
# ('2026-07-21 14:29:16', 'DEV012', 'Pressure_Sensor', 'OfficeB', 1005.88)
# ('2026-07-21 14:29:17', 'DEV013', 'Humidity_Sensor', 'Lab2', 52.66)
# ('2026-07-21 14:29:18', 'DEV014', 'Light_Sensor', 'OfficeB', 840.38)
# ('2026-07-21 14:29:19', 'DEV015', 'Pressure_Sensor', 'Warehouse', 1009.42)
# ('2026-07-21 14:29:20', 'DEV016', 'Temperature_Sensor', 'Lab1', 26.67)
# ('2026-07-21 14:29:21', 'DEV017', 'Pressure_Sensor', 'OfficeB', 992.42)
# ('2026-07-21 14:29:22', 'DEV018', 'Pressure_Sensor', 'OfficeA', 980.41)
# ('2026-07-21 14:29:23', 'DEV019', 'Pressure_Sensor', 'OfficeA', 1010.47)
# ('2026-07-21 14:29:24', 'DEV020', 'Pressure_Sensor', 'OfficeB', 1026.0)
# ('2026-07-21 14:29:25', 'DEV021', 'Light_Sensor', 'Lab1', 457.67)
# ('2026-07-21 14:29:26', 'DEV022', 'Light_Sensor', 'Lab1', 296.87)
# ('2026-07-21 14:29:27', 'DEV023', 'Pressure_Sensor', 'OfficeA', 1022.24)
# ('2026-07-21 14:29:28', 'DEV024', 'Pressure_Sensor', 'OfficeB', 1017.44)
# ('2026-07-21 14:29:29', 'DEV025', 'Humidity_Sensor', 'Warehouse', 47.68)
# ('2026-07-21 14:29:30', 'DEV026', 'Pressure_Sensor', 'OfficeA', 1010.86)
# ('2026-07-21 14:29:31', 'DEV027', 'Pressure_Sensor', 'Warehouse', 981.68)
# ('2026-07-21 14:29:32', 'DEV028', 'Light_Sensor', 'Lab2', 690.29)
# ('2026-07-21 14:29:33', 'DEV029', 'Light_Sensor', 'Lab2', 336.87)
# ('2026-07-21 14:29:34', 'DEV030', 'Light_Sensor', 'OfficeA', 241.32)
# ('2026-07-21 14:29:35', 'DEV031', 'Humidity_Sensor', 'Lab1', 34.1)
# ('2026-07-21 14:29:36', 'DEV032', 'Light_Sensor', 'OfficeB', 459.5)
# ('2026-07-21 14:29:37', 'DEV033', 'Pressure_Sensor', 'OfficeB', 983.11)
# ('2026-07-21 14:29:38', 'DEV034', 'Temperature_Sensor', 'Lab2', 19.43)
# ('2026-07-21 14:29:39', 'DEV035', 'Humidity_Sensor', 'OfficeA', 62.7)
# ('2026-07-21 14:29:40', 'DEV036', 'Humidity_Sensor', 'Lab2', 66.11)
# ('2026-07-21 14:29:41', 'DEV037', 'Light_Sensor', 'OfficeB', 361.56)
# ('2026-07-21 14:29:42', 'DEV038', 'Light_Sensor', 'Lab2', 712.66)
# ('2026-07-21 14:29:43', 'DEV039', 'Light_Sensor', 'OfficeB', 586.74)
# ('2026-07-21 14:29:44', 'DEV040', 'Light_Sensor', 'OfficeA', 310.83)
# ('2026-07-21 14:29:45', 'DEV041', 'Pressure_Sensor', 'Lab1', 1015.52)
# ('2026-07-21 14:29:46', 'DEV042', 'Pressure_Sensor', 'Warehouse', 1009.57)
# ('2026-07-21 14:29:47', 'DEV043', 'Humidity_Sensor', 'OfficeB', 48.67)
# ('2026-07-21 14:29:48', 'DEV044', 'Humidity_Sensor', 'Lab1', 79.28)
# ('2026-07-21 14:29:49', 'DEV045', 'Temperature_Sensor', 'Lab1', 29.94)
# ('2026-07-21 14:29:50', 'DEV046', 'Pressure_Sensor', 'OfficeA', 1023.63)
# ('2026-07-21 14:29:51', 'DEV047', 'Pressure_Sensor', 'OfficeB', 980.3)
# ('2026-07-21 14:29:52', 'DEV048', 'Pressure_Sensor', 'Lab1', 986.98)
# ('2026-07-21 14:29:53', 'DEV049', 'Temperature_Sensor', 'Warehouse', 27.58)
# ('2026-07-21 14:29:54', 'DEV050', 'Light_Sensor', 'OfficeA', 978.52)
# ('2026-07-21 14:29:55', 'DEV051', 'Humidity_Sensor', 'OfficeA', 70.8)
# ('2026-07-21 14:29:56', 'DEV052', 'Light_Sensor', 'OfficeB', 287.66)
# ('2026-07-21 14:29:57', 'DEV053', 'Temperature_Sensor', 'Warehouse', 26.85)
# ('2026-07-21 14:29:58', 'DEV054', 'Temperature_Sensor', 'OfficeA', 19.16)
# ('2026-07-21 14:29:59', 'DEV055', 'Humidity_Sensor', 'Lab1', 74.21)
# ('2026-07-21 14:30:00', 'DEV056', 'Pressure_Sensor', 'OfficeB', 998.34)
# ('2026-07-21 14:30:01', 'DEV057', 'Humidity_Sensor', 'Lab2', 47.93)
# ('2026-07-21 14:30:02', 'DEV058', 'Temperature_Sensor', 'Lab1', 18.34)
# ('2026-07-21 14:30:03', 'DEV059', 'Pressure_Sensor', 'Lab1', 985.68)
# ('2026-07-21 14:30:04', 'DEV060', 'Pressure_Sensor', 'OfficeA', 1012.52)
# ('2026-07-21 14:30:05', 'DEV061', 'Humidity_Sensor', 'Lab1', 56.75)
# ('2026-07-21 14:30:06', 'DEV062', 'Light_Sensor', 'Warehouse', 363.58)
# ('2026-07-21 14:30:07', 'DEV063', 'Humidity_Sensor', 'OfficeB', 63.37)
# ('2026-07-21 14:30:08', 'DEV064', 'Light_Sensor', 'OfficeA', 960.09)
# ('2026-07-21 14:30:09', 'DEV065', 'Pressure_Sensor', 'Warehouse', 1000.59)
# ('2026-07-21 14:30:10', 'DEV066', 'Humidity_Sensor', 'Lab1', 44.61)
# ('2026-07-21 14:30:11', 'DEV067', 'Pressure_Sensor', 'OfficeB', 1015.24)
# ('2026-07-21 14:30:12', 'DEV068', 'Pressure_Sensor', 'OfficeA', 987.18)
# ('2026-07-21 14:30:13', 'DEV069', 'Pressure_Sensor', 'OfficeB', 1016.39)
# ('2026-07-21 14:30:14', 'DEV070', 'Temperature_Sensor', 'Lab1', 18.76)
# ('2026-07-21 14:30:15', 'DEV071', 'Temperature_Sensor', 'OfficeB', 28.99)
# ('2026-07-21 14:30:16', 'DEV072', 'Humidity_Sensor', 'OfficeB', 34.05)
# ('2026-07-21 14:30:17', 'DEV073', 'Temperature_Sensor', 'OfficeA', 29.65)
# ('2026-07-21 14:30:18', 'DEV074', 'Humidity_Sensor', 'Warehouse', 69.21)
# ('2026-07-21 14:30:19', 'DEV075', 'Pressure_Sensor', 'Lab1', 990.64)
# ('2026-07-21 14:30:20', 'DEV076', 'Pressure_Sensor', 'OfficeA', 998.49)
# ('2026-07-21 14:30:21', 'DEV077', 'Temperature_Sensor', 'Lab1', 19.32)
# ('2026-07-21 14:30:22', 'DEV078', 'Pressure_Sensor', 'Lab1', 1009.97)
# ('2026-07-21 14:30:23', 'DEV079', 'Temperature_Sensor', 'Warehouse', 26.93)
# ('2026-07-21 14:30:24', 'DEV080', 'Pressure_Sensor', 'Lab1', 981.87)
# ('2026-07-21 14:30:25', 'DEV081', 'Humidity_Sensor', 'Lab2', 54.55)
# ('2026-07-21 14:30:26', 'DEV082', 'Pressure_Sensor', 'OfficeB', 980.58)
# ('2026-07-21 14:30:27', 'DEV083', 'Temperature_Sensor', 'Lab2', 20.37)
# ('2026-07-21 14:30:28', 'DEV084', 'Temperature_Sensor', 'Warehouse', 27.98)
# ('2026-07-21 14:30:29', 'DEV085', 'Pressure_Sensor', 'Lab1', 1023.48)
# ('2026-07-21 14:30:30', 'DEV086', 'Light_Sensor', 'OfficeA', 383.97)
# ('2026-07-21 14:30:31', 'DEV087', 'Humidity_Sensor', 'Lab2', 51.09)
# ('2026-07-21 14:30:32', 'DEV088', 'Light_Sensor', 'OfficeB', 822.9)
# ('2026-07-21 14:30:33', 'DEV089', 'Humidity_Sensor', 'Lab2', 75.67)
# ('2026-07-21 14:30:34', 'DEV090', 'Humidity_Sensor', 'Lab1', 32.95)
# ('2026-07-21 14:30:35', 'DEV091', 'Light_Sensor', 'Warehouse', 140.28)
# ('2026-07-21 14:30:36', 'DEV092', 'Humidity_Sensor', 'Warehouse', 75.89)
# ('2026-07-21 14:30:37', 'DEV093', 'Temperature_Sensor', 'OfficeB', 27.54)
# ('2026-07-21 14:30:38', 'DEV094', 'Light_Sensor', 'Lab1', 882.49)
# ('2026-07-21 14:30:39', 'DEV095', 'Temperature_Sensor', 'OfficeB', 23.81)
# ('2026-07-21 14:30:40', 'DEV096', 'Light_Sensor', 'Lab1', 758.3)
# ('2026-07-21 14:30:41', 'DEV097', 'Pressure_Sensor', 'Lab1', 998.46)
# ('2026-07-21 14:30:42', 'DEV098', 'Humidity_Sensor', 'Warehouse', 31.59)
# ('2026-07-21 14:30:43', 'DEV099', 'Humidity_Sensor', 'Lab1', 74.01)
# ('2026-07-21 14:30:44', 'DEV100', 'Humidity_Sensor', 'OfficeA', 73.71)
# [{'timestamp': '2026-07-21 14:29:07', 'device_id': 'DEV003', 'location': 'OfficeB', 'temperature_celsius': 21.8}, {'timestamp': '2026-07-21 14:29:12', 'device_id': 'DEV008', 'location': 'Lab1', 'temperature_celsius': 28.96}, {'timestamp': '2026-07-21 14:29:20', 'device_id': 'DEV016', 'location': 'Lab1', 'temperature_celsius': 26.67}, {'timestamp': '2026-07-21 14:29:38', 'device_id': 'DEV034', 'location': 'Lab2', 'temperature_celsius': 19.43}, {'timestamp': '2026-07-21 14:29:49', 'device_id': 'DEV045', 'location': 'Lab1', 'temperature_celsius': 29.94}, {'timestamp': '2026-07-21 14:29:53', 'device_id': 'DEV049', 'location': 'Warehouse', 'temperature_celsius': 27.58}, {'timestamp': '2026-07-21 14:29:57', 'device_id': 'DEV053', 'location': 'Warehouse', 'temperature_celsius': 26.85}, {'timestamp': '2026-07-21 14:29:58', 'device_id': 'DEV054', 'location': 'OfficeA', 'temperature_celsius': 19.16}, {'timestamp': '2026-07-21 14:30:02', 'device_id': 'DEV058', 'location': 'Lab1', 'temperature_celsius': 18.34}, {'timestamp': '2026-07-21 14:30:14', 'device_id': 'DEV070', 'location': 'Lab1', 'temperature_celsius': 18.76}, {'timestamp': '2026-07-21 14:30:15', 'device_id': 'DEV071', 'location': 'OfficeB', 'temperature_celsius': 28.99}, {'timestamp': '2026-07-21 14:30:17', 'device_id': 'DEV073', 'location': 'OfficeA', 'temperature_celsius': 29.65}, {'timestamp': '2026-07-21 14:30:21', 'device_id': 'DEV077', 'location': 'Lab1', 'temperature_celsius': 19.32}, {'timestamp': '2026-07-21 14:30:23', 'device_id': 'DEV079', 'location': 'Warehouse', 'temperature_celsius': 26.93}, {'timestamp': '2026-07-21 14:30:27', 'device_id': 'DEV083', 'location': 'Lab2', 'temperature_celsius': 20.37}, {'timestamp': '2026-07-21 14:30:28', 'device_id': 'DEV084', 'location': 'Warehouse', 'temperature_celsius': 27.98}, {'timestamp': '2026-07-21 14:30:37', 'device_id': 'DEV093', 'location': 'OfficeB', 'temperature_celsius': 27.54}, {'timestamp': '2026-07-21 14:30:39', 'device_id': 'DEV095', 'location': 'OfficeB', 'temperature_celsius': 23.81}]
# {'Lab2', 'Warehouse', 'OfficeB', 'OfficeA', 'Lab1'}
# {'Temperature_Sensor': (18.34, 29.94), 'Humidity_Sensor': (31.59, 79.28), 'Pressure_Sensor': (980.3, 1026.0), 'Light_Sensor': (140.28, 978.52)}
#
# --- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---
# [('2026-07-21 14:29:14', 'DEV010', 'Pressure_Sensor', 'OfficeA', 1001.42), ('2026-07-21 14:29:15', 'DEV011', 'Pressure_Sensor', 'OfficeB', 985.68), ('2026-07-21 14:29:16', 'DEV012', 'Pressure_Sensor', 'OfficeB', 1005.88), ('2026-07-21 14:29:17', 'DEV013', 'Humidity_Sensor', 'Lab2', 52.66), ('2026-07-21 14:29:18', 'DEV014', 'Light_Sensor', 'OfficeB', 840.38), ('2026-07-21 14:29:19', 'DEV015', 'Pressure_Sensor', 'Warehouse', 1009.42), ('2026-07-21 14:29:20', 'DEV016', 'Temperature_Sensor', 'Lab1', 26.67), ('2026-07-21 14:29:21', 'DEV017', 'Pressure_Sensor', 'OfficeB', 992.42), ('2026-07-21 14:29:22', 'DEV018', 'Pressure_Sensor', 'OfficeA', 980.41), ('2026-07-21 14:29:23', 'DEV019', 'Pressure_Sensor', 'OfficeA', 1010.47), ('2026-07-21 14:29:24', 'DEV020', 'Pressure_Sensor', 'OfficeB', 1026.0)]
# [('2026-07-21 14:29:05', 'DEV001', 'Humidity_Sensor', 'OfficeA', 41.66), ('2026-07-21 14:29:10', 'DEV006', 'Pressure_Sensor', 'OfficeB', 1020.41), ('2026-07-21 14:29:15', 'DEV011', 'Pressure_Sensor', 'OfficeB', 985.68), ('2026-07-21 14:29:20', 'DEV016', 'Temperature_Sensor', 'Lab1', 26.67), ('2026-07-21 14:29:25', 'DEV021', 'Light_Sensor', 'Lab1', 457.67), ('2026-07-21 14:29:30', 'DEV026', 'Pressure_Sensor', 'OfficeA', 1010.86), ('2026-07-21 14:29:35', 'DEV031', 'Humidity_Sensor', 'Lab1', 34.1), ('2026-07-21 14:29:40', 'DEV036', 'Humidity_Sensor', 'Lab2', 66.11), ('2026-07-21 14:29:45', 'DEV041', 'Pressure_Sensor', 'Lab1', 1015.52), ('2026-07-21 14:29:50', 'DEV046', 'Pressure_Sensor', 'OfficeA', 1023.63), ('2026-07-21 14:29:55', 'DEV051', 'Humidity_Sensor', 'OfficeA', 70.8), ('2026-07-21 14:30:00', 'DEV056', 'Pressure_Sensor', 'OfficeB', 998.34), ('2026-07-21 14:30:05', 'DEV061', 'Humidity_Sensor', 'Lab1', 56.75), ('2026-07-21 14:30:10', 'DEV066', 'Humidity_Sensor', 'Lab1', 44.61), ('2026-07-21 14:30:15', 'DEV071', 'Temperature_Sensor', 'OfficeB', 28.99), ('2026-07-21 14:30:20', 'DEV076', 'Pressure_Sensor', 'OfficeA', 998.49), ('2026-07-21 14:30:25', 'DEV081', 'Humidity_Sensor', 'Lab2', 54.55), ('2026-07-21 14:30:30', 'DEV086', 'Light_Sensor', 'OfficeA', 383.97), ('2026-07-21 14:30:35', 'DEV091', 'Light_Sensor', 'Warehouse', 140.28), ('2026-07-21 14:30:40', 'DEV096', 'Light_Sensor', 'Lab1', 758.3)]
# Programming
# nohtyP
# Light_Sensor
# Sensor
#
# --- Task 2: Function Definitions and Usage ---
#
# --- Task 3: Core Library Usage ---
#
# Directory 'sensor_reports' created.
#
# Duration of data collection: 0 days, 0 hours, 1 minutes.
# [190, 111, 118, 166, 135]
#
# --- Task 4: File I/O ---
#
# Temperature report written to 'sensor_reports/temperature_report.txt'.
# First 3 lines of the report:
# [2026-07-21 14:29:07]Device DEV003at OfficeB: 21.8C
# [2026-07-21 14:29:12]Device DEV008at Lab1: 28.96C
# [2026-07-21 14:29:20]Device DEV016at Lab1: 26.67C
#
# --- Exercise Complete! ---
# Great job completing the intermediate Python exercise.
# Review your code and outputs to ensure correctness and understanding of all concepts.
# Consider adding more complex scenarios or user inputs for further practice.
